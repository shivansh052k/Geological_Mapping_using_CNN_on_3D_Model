# %%
#!pip install tensorboardX
# !pip install --upgrade pip setuptools wheel
# !pip install scipy
# !pip install torch-encoding
# !pip install ninja
# !pip install --upgrade --no-cache-dir gdown==4.3.0
# !pip install rioxarray
#%cd GSCNN-apply-to-airborne-magnetic
import export_results as er
from export_results import images, nets
# Out:
# /Users/shivansh052k/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
er.import_image(images)
# Out:
# Label(value='Import an image to work on || Importez une image de travail')
# HBox(children=(Dropdown(description='Test Images :', options=('malartic_synt', 'malartic', "val d'or", 'ashram…
# Label(value='or download your own image || ou téléchargez votre image')
# HBox(children=(Textarea(value='https://drive.google.com/file/d/1J8UX-fTlHY-NqyF15IYQrfXANHqZJY4H/view?usp=shar…
# HBox(children=(Textarea(value='malartic_synt', description='image name', placeholder='Name your image'), Label…
# HBox(children=(Dropdown(description='Colormap :', options=('jet', 'viridis', 'plasma', 'inferno', 'magma', 'ci…
# HBox(children=(IntText(value=50, description='Pixel size'), Checkbox(value=False, description='Smooth', indent…
# Button(description='Get Image', style=ButtonStyle())

# %%
er.load_net()
# Out:
# HBox(children=(Dropdown(description='Weights', options=('weight_syntmag',), value='weight_syntmag'), Label(val…
# Button(description='Load', style=ButtonStyle())
# Access denied with the following error:
# num class :  3
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1Cfp_UtA_Rit1xCzCYldxag0cfIVJVZE6
#
# /Users/shivansh052k/Documents/Github/Geological_Mapping_using_CNN_on_3D_Model/network/mynn.py:30: FutureWarning: `nn.init.kaiming_normal` is now deprecated in favor of `nn.init.kaiming_normal_`.
#   nn.init.kaiming_normal(module.weight)
# /Users/shivansh052k/Documents/Github/Geological_Mapping_using_CNN_on_3D_Model/optimizer.py:50: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(snapshot, map_location=torch.device('cpu'))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/Github/Geological_Mapping_using_CNN_on_3D_Model/export_results.py:610, in load_net.<locals>.load_weigth(obj)
#     609 def load_weigth(obj):
# --> 610   net = prepare_net(weight_path[wgh.value], wgh.value)
#     611   nets[wgh.value] = net
#
# File ~/Documents/Github/Geological_Mapping_using_CNN_on_3D_Model/export_results.py:263, in prepare_net(weight_path, name)
#     261 else:
#     262   net = get_net_use(args)
# --> 263   net, _ = restore_snapshot(args, net, None, output_path)
#     265 return net
#
# File ~/Documents/Github/Geological_Mapping_using_CNN_on_3D_Model/optimizer.py:50, in restore_snapshot(args, net, optimizer, snapshot)
#      49 def restore_snapshot(args, net, optimizer, snapshot):
# ---> 50     checkpoint = torch.load(snapshot, map_location=torch.device('cpu'))
#      51     logging.info("Load Compelete")
#      52     if args.sgd_finetuned:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:1065, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1062 if 'encoding' not in pickle_load_args.keys():
#    1063     pickle_load_args['encoding'] = 'utf-8'
# -> 1065 with _open_file_like(f, 'rb') as opened_file:
#    1066     if _is_zipfile(opened_file):
#    1067         # The zipfile reader is going to advance the current file position.
#    1068         # If we want to actually tail call to torch.jit.load, we need to
#    1069         # reset back to the original position.
#    1070         orig_position = opened_file.tell()
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:468, in _open_file_like(name_or_buffer, mode)
#     466 def _open_file_like(name_or_buffer, mode):
#     467     if _is_path(name_or_buffer):
# --> 468         return _open_file(name_or_buffer, mode)
#     469     else:
#     470         if 'w' in mode:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:449, in _open_file.__init__(self, name, mode)
#     448 def __init__(self, name, mode):
# --> 449     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/GSCNN-apply-to-airborne-magnetic/weight_syntmag'
